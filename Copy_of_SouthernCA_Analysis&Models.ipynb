# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremiahsnipes/motorcycle_risk_project/blob/main/Copy_of_SouthernCA_Analysis%26Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Motorcycle Prediction Project

import pandas as pd

crashes_url = "https://raw.githubusercontent.com/jeremiahsnipes/motorcycle_risk_project/main/data/socal_motorcycle_crashes_updated.csv"
registration_url = "https://raw.githubusercontent.com/jeremiahsnipes/motorcycle_risk_project/main/data/socal_registration.csv"

df_crashes = pd.read_csv(crashes_url)
df_registration = pd.read_csv(registration_url)

df_crashes.head(), df_registration.head()
# Out:
# (   ACCIDENT_YEAR  JURIS COLLISION_DATE  COLLISION_TIME  DAY_OF_WEEK  \
#  0           2021   1942     2021-01-11            1440            1
#  1           2021   1942     2021-01-10            1153            7
#  2           2021   1942     2021-01-26            1400            2
#  3           2021   1942     2021-01-19            1330            2
#  4           2021   1933     2021-01-25             856            1
#
#     CHP_SHIFT INTERSECTION WEATHER_1 WEATHER_2 STATE_HWY_IND  ...  \
#  0          5            N         A         -             N  ...
#  1          5            N         A         -             N  ...
#  2          5            Y         A         -             N  ...
#  3          5            Y         A         -             N  ...
#  4          5            N         A         -             N  ...
#
#    COUNT_MC_INJURED   LATITUDE   LONGITUDE       COUNTY         CITY  \
#  0                0        NaN         NaN  LOS ANGELES  LOS ANGELES
#  1                1        NaN         NaN  LOS ANGELES  LOS ANGELES
#  2                1        NaN         NaN  LOS ANGELES  LOS ANGELES
#  3                1        NaN         NaN  LOS ANGELES  LOS ANGELES
#  4                1  33.936798 -118.343903  LOS ANGELES    INGLEWOOD
#
#        POINT_X    POINT_Y IS_WEEKEND TIME_OF_DAY SEVERE_FATAL
#  0 -118.468544  34.071571          0      Midday            1
#  1 -118.388931  34.036381          1      Midday            0
#  2 -118.344032  34.068905          0      Midday            1
#  3 -118.299980  34.049068          0      Midday            0
#  4 -118.343918  33.936653          0     Morning            0
#
#  [5 rows x 48 columns],
#          County    Year   Total Registrations   Motorcycle Registration  \
#  0  LOS ANGELES  2021.0              7989032.0                 155065.0
#  1  LOS ANGELES  2022.0              7848098.0                 150464.0
#  2  LOS ANGELES  2023.0              7777406.0                 144037.0
#  3  LOS ANGELES  2024.0              7776731.0                 139137.0
#  4    RIVERSIDE  2021.0              2196259.0                  51917.0
#
#     Auto Registration  Truck Registration  Other Registration  Unnamed: 7  \
#  0          6386830.0           1150957.0            296180.0         NaN
#  1          6291868.0           1136152.0            269614.0         NaN
#  2          6229731.0           1123162.0            280476.0         NaN
#  3          6235778.0           1126000.0            275816.0         NaN
#  4          1529684.0            426284.0            188374.0         NaN
#
#     Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
#  0         NaN         NaN          NaN          NaN          NaN          NaN
#  1         NaN         NaN          NaN          NaN          NaN          NaN
#  2         NaN         NaN          NaN          NaN          NaN          NaN
#  3         NaN         NaN          NaN          NaN          NaN          NaN
#  4         NaN         NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 14
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN  )

# %%
df_registration.columns
# Out:
# Index(['County', 'Year', ' Total Registrations ', 'Motorcycle Registration',
#        'Auto Registration', 'Truck Registration', 'Other Registration',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
df_crashes.columns
# Out:
# Index(['ACCIDENT_YEAR', 'JURIS', 'COLLISION_DATE', 'COLLISION_TIME',
#        'DAY_OF_WEEK', 'CHP_SHIFT', 'INTERSECTION', 'WEATHER_1', 'WEATHER_2',
#        'STATE_HWY_IND', 'LOCATION_TYPE', 'RAMP_INTERSECTION', 'TOW_AWAY',
#        'COLLISION_SEVERITY', 'NUMBER_KILLED', 'NUMBER_INJURED', 'PARTY_COUNT',
#        'PRIMARY_COLL_FACTOR', 'PCF_CODE_OF_VIOL', 'PCF_VIOL_CATEGORY',
#        'PCF_VIOLATION', 'PCF_VIOL_SUBSECTION', 'HIT_AND_RUN',
#        'TYPE_OF_COLLISION', 'ROAD_SURFACE', 'ROAD_COND_1', 'ROAD_COND_2',
#        'LIGHTING', 'CONTROL_DEVICE', 'CHP_ROAD_TYPE', 'MOTORCYCLE_ACCIDENT',
#        'ALCOHOL_INVOLVED', 'STWD_VEHTYPE_AT_FAULT', 'CHP_VEHTYPE_AT_FAULT',
#        'COUNT_SEVERE_INJ', 'COUNT_VISIBLE_INJ', 'COUNT_COMPLAINT_PAIN',
#        'COUNT_MC_KILLED', 'COUNT_MC_INJURED', 'LATITUDE', 'LONGITUDE',
#        'COUNTY', 'CITY', 'POINT_X', 'POINT_Y', 'IS_WEEKEND', 'TIME_OF_DAY',
#        'SEVERE_FATAL'],
#       dtype='object')

# %%
# Standardize crash dataset column names
df_crashes = df_crashes.rename(columns={
    "COUNTY": "County",
    "ACCIDENT_YEAR": "Year"
})

# Clean registration dataset (strip whitespace)
df_registration.columns = df_registration.columns.str.strip()

# Drop Unamed Columns
df_registration = df_registration.loc[:, ~df_registration.columns.str.contains("Unnamed")]

df_registration = df_registration.rename(columns={
    "County": "County",
    "Year": "Year"
})

# %%
df_merged = df_crashes.merge(
    df_registration,
    on=["County", "Year"],
    how="left"
)

df_merged.head()
# Out:
#    Year  JURIS COLLISION_DATE  COLLISION_TIME  DAY_OF_WEEK  CHP_SHIFT  \
# 0  2021   1942     2021-01-11            1440            1          5
# 1  2021   1942     2021-01-10            1153            7          5
# 2  2021   1942     2021-01-26            1400            2          5
# 3  2021   1942     2021-01-19            1330            2          5
# 4  2021   1933     2021-01-25             856            1          5
#
#   INTERSECTION WEATHER_1 WEATHER_2 STATE_HWY_IND  ...     POINT_X    POINT_Y  \
# 0            N         A         -             N  ... -118.468544  34.071571
# 1            N         A         -             N  ... -118.388931  34.036381
# 2            Y         A         -             N  ... -118.344032  34.068905
# 3            Y         A         -             N  ... -118.299980  34.049068
# 4            N         A         -             N  ... -118.343918  33.936653
#
#   IS_WEEKEND  TIME_OF_DAY  SEVERE_FATAL  Total Registrations  \
# 0          0       Midday             1            7989032.0
# 1          1       Midday             0            7989032.0
# 2          0       Midday             1            7989032.0
# 3          0       Midday             0            7989032.0
# 4          0      Morning             0            7989032.0
#
#    Motorcycle Registration Auto Registration Truck Registration  \
# 0                 155065.0         6386830.0          1150957.0
# 1                 155065.0         6386830.0          1150957.0
# 2                 155065.0         6386830.0          1150957.0
# 3                 155065.0         6386830.0          1150957.0
# 4                 155065.0         6386830.0          1150957.0
#
#   Other Registration
# 0           296180.0
# 1           296180.0
# 2           296180.0
# 3           296180.0
# 4           296180.0
#
# [5 rows x 53 columns]

# %%
df_merged.columns.tolist()
# Out:
# ['Year',
#  'JURIS',
#  'COLLISION_DATE',
#  'COLLISION_TIME',
#  'DAY_OF_WEEK',
#  'CHP_SHIFT',
#  'INTERSECTION',
#  'WEATHER_1',
#  'WEATHER_2',
#  'STATE_HWY_IND',
#  'LOCATION_TYPE',
#  'RAMP_INTERSECTION',
#  'TOW_AWAY',
#  'COLLISION_SEVERITY',
#  'NUMBER_KILLED',
#  'NUMBER_INJURED',
#  'PARTY_COUNT',
#  'PRIMARY_COLL_FACTOR',
#  'PCF_CODE_OF_VIOL',
#  'PCF_VIOL_CATEGORY',
#  'PCF_VIOLATION',
#  'PCF_VIOL_SUBSECTION',
#  'HIT_AND_RUN',
#  'TYPE_OF_COLLISION',
#  'ROAD_SURFACE',
#  'ROAD_COND_1',
#  'ROAD_COND_2',
#  'LIGHTING',
#  'CONTROL_DEVICE',
#  'CHP_ROAD_TYPE',
#  'MOTORCYCLE_ACCIDENT',
#  'ALCOHOL_INVOLVED',
#  'STWD_VEHTYPE_AT_FAULT',
#  'CHP_VEHTYPE_AT_FAULT',
#  'COUNT_SEVERE_INJ',
#  'COUNT_VISIBLE_INJ',
#  'COUNT_COMPLAINT_PAIN',
#  'COUNT_MC_KILLED',
#  'COUNT_MC_INJURED',
#  'LATITUDE',
#  'LONGITUDE',
#  'County',
#  'CITY',
#  'POINT_X',
#  'POINT_Y',
#  'IS_WEEKEND',
#  'TIME_OF_DAY',
#  'SEVERE_FATAL',
#  'Total Registrations',
#  'Motorcycle Registration',
#  'Auto Registration',
#  'Truck Registration',
#  'Other Registration']

# %%
# Confirm Classes in Outcome Variable (COLLISION_SEVERITY = KABCO)
# - 1 = Fatal , 2 = Severe Injury , 3 = Visible Injury , 4 = Complaint of Pain
# 5 = Property Damage Only

df_merged['COLLISION_SEVERITY'].value_counts().sort_index()
# Out:
# COLLISION_SEVERITY
# 1     964
# 2    5033
# 3    8865
# 4    4859
# Name: count, dtype: int64

# %%
# Percentages in Outcome Classes
df_merged['COLLISION_SEVERITY'].value_counts(normalize=True).sort_index()
# Out:
# COLLISION_SEVERITY
# 1    0.048882
# 2    0.255210
# 3    0.449521
# 4    0.246387
# Name: proportion, dtype: float64

# %% [markdown]
# We see strong Class Imbalance since 4.89% is fatal, 25.52% is Severe Injury, 44.95% is Visible Injury, and 24.64% is Complaint of Pain - Note Class 5 Property Damage Only is not included.

# %%
# Predictor and Outcome List

predictors = [
    'Year', 'DAY_OF_WEEK', 'COLLISION_TIME', 'TIME_OF_DAY', 'IS_WEEKEND',
    'WEATHER_1', 'LIGHTING', 'ROAD_SURFACE', 'ROAD_COND_1',
    'STATE_HWY_IND', 'LOCATION_TYPE', 'INTERSECTION', 'RAMP_INTERSECTION',
    'CHP_ROAD_TYPE', 'CONTROL_DEVICE',
    'TYPE_OF_COLLISION', 'PRIMARY_COLL_FACTOR', 'PCF_CODE_OF_VIOL',
    'PCF_VIOL_CATEGORY', 'PCF_VIOLATION', 'PCF_VIOL_SUBSECTION',
    'HIT_AND_RUN', 'TOW_AWAY', 'PARTY_COUNT', 'ALCOHOL_INVOLVED',
    'STWD_VEHTYPE_AT_FAULT', 'CHP_VEHTYPE_AT_FAULT',
    'LATITUDE', 'LONGITUDE', 'County', 'CITY',
    'Total Registrations', 'Motorcycle Registration',
    'Auto Registration', 'Truck Registration', 'Other Registration'
]

outcome = 'COLLISION_SEVERITY'

# %% [markdown]
# The final predictor set reflects a systematic effort to construct a modeling framework that is both statistically valid and scientifically defensible. Several variables were intentionally removed because they represented direct measures of crash severity. Fields such as NUMBER_KILLED, NUMBER_INJURED, COUNT_SEVERE_INJ, COUNT_VISIBLE_INJ, COUNT_COMPLAINT_PAIN, COUNT_MC_KILLED, and COUNT_MC_INJURED quantify the injury outcomes of the crash itself. Including these variables would have introduced outcome leakage, allowing the model to infer severity directly from injury counts rather than from the environmental, behavioral, and roadway conditions that precede the crash. Removing these fields ensures that the model predicts severity based on causal or contributory factors rather than on variables that are deterministically linked to the outcome.
# Other variables were excluded because they were redundant or offered limited analytical value. For example, WEATHER_2 was removed due to its sparse and often duplicative nature relative to WEATHER_1. In SWITRS data, secondary weather conditions are frequently missing or simply restate the primary condition, and retaining them would have increased dimensionality without improving predictive performance. Similarly, POINT_X and POINT_Y were omitted because they duplicate the information contained in LATITUDE and LONGITUDE. Eliminating redundant spatial fields reduces multicollinearity and simplifies downstream modeling. Variables such as JURIS and CHP_SHIFT were also removed because they tend to act as proxies for more interpretable predictors like county, city, or time of day. Their exclusion supports a cleaner, more interpretable model structure.
# The resulting predictor set emphasizes variables that capture meaningful temporal, environmental, roadway, behavioral, and geospatial characteristics of each crash. These predictors represent conditions present before or during the collision and therefore align with the conceptual goal of modeling severity as a function of contributing factors rather than consequences. The inclusion of registration-based exposure variables further strengthens the analytical framework by contextualizing crash counts within the broader population of registered vehicles. Collectively, these decisions produce a predictor set that is methodologically sound, free of outcome leakage, and well-suited for rigorous statistical modeling and machine learning applications in crash‑severity research.

# %%
# Creating Clean Model Dataframe with Desired Variables

model_df = df_merged[predictors + [outcome]].copy()
model_df.head()
# Out:
#    Year  DAY_OF_WEEK  COLLISION_TIME TIME_OF_DAY  IS_WEEKEND WEATHER_1  \
# 0  2021            1            1440      Midday           0         A
# 1  2021            7            1153      Midday           1         A
# 2  2021            2            1400      Midday           0         A
# 3  2021            2            1330      Midday           0         A
# 4  2021            1             856     Morning           0         A
#
#   LIGHTING ROAD_SURFACE ROAD_COND_1 STATE_HWY_IND  ...   LATITUDE   LONGITUDE  \
# 0        A            A           H             N  ...        NaN         NaN
# 1        A            A           H             N  ...        NaN         NaN
# 2        A            A           H             N  ...        NaN         NaN
# 3        A            A           H             N  ...        NaN         NaN
# 4        A            A           H             N  ...  33.936798 -118.343903
#
#         County         CITY Total Registrations Motorcycle Registration  \
# 0  LOS ANGELES  LOS ANGELES           7989032.0                155065.0
# 1  LOS ANGELES  LOS ANGELES           7989032.0                155065.0
# 2  LOS ANGELES  LOS ANGELES           7989032.0                155065.0
# 3  LOS ANGELES  LOS ANGELES           7989032.0                155065.0
# 4  LOS ANGELES    INGLEWOOD           7989032.0                155065.0
#
#   Auto Registration Truck Registration Other Registration  COLLISION_SEVERITY
# 0         6386830.0          1150957.0           296180.0                   1
# 1         6386830.0          1150957.0           296180.0                   3
# 2         6386830.0          1150957.0           296180.0                   2
# 3         6386830.0          1150957.0           296180.0                   4
# 4         6386830.0          1150957.0           296180.0                   4
#
# [5 rows x 37 columns]

# %%
# Assess for Missing Values

model_df.isna().sum().sort_values(ascending=False)
# Out:
# RAMP_INTERSECTION          19170
# ALCOHOL_INVOLVED           18247
# LOCATION_TYPE              14135
# PCF_VIOL_SUBSECTION        11627
# LONGITUDE                   6212
# LATITUDE                    6212
# PCF_VIOLATION                963
# CHP_VEHTYPE_AT_FAULT         359
# TOW_AWAY                     142
# STATE_HWY_IND                 12
# Year                           0
# COLLISION_TIME                 0
# DAY_OF_WEEK                    0
# IS_WEEKEND                     0
# TIME_OF_DAY                    0
# CHP_ROAD_TYPE                  0
# LIGHTING                       0
# INTERSECTION                   0
# ROAD_SURFACE                   0
# ROAD_COND_1                    0
# WEATHER_1                      0
# PCF_CODE_OF_VIOL               0
# PCF_VIOL_CATEGORY              0
# TYPE_OF_COLLISION              0
# PRIMARY_COLL_FACTOR            0
# CONTROL_DEVICE                 0
# HIT_AND_RUN                    0
# PARTY_COUNT                    0
# STWD_VEHTYPE_AT_FAULT          0
# County                         0
# CITY                           0
# Total Registrations            0
# Motorcycle Registration        0
# Auto Registration              0
# Truck Registration             0
# Other Registration             0
# COLLISION_SEVERITY             0
# dtype: int64

# %%
# Handle Categorical Variable Missingness By inputting "Unkown"

cat_cols = [
    'RAMP_INTERSECTION', 'ALCOHOL_INVOLVED', 'LOCATION_TYPE',
    'PCF_VIOL_SUBSECTION', 'PCF_VIOLATION', 'CHP_VEHTYPE_AT_FAULT',
    'TOW_AWAY', 'STATE_HWY_IND'
]

for col in cat_cols:
    model_df[col] = model_df[col].fillna("Unknown")

# %%
# Handle Numberic Variables by Filling With Median for Lat/Long

num_cols = ['LATITUDE', 'LONGITUDE']

for col in num_cols:
    model_df[col] = model_df[col].fillna(model_df[col].median())

# %% [markdown]
# In this stage of the analysis, the objective is to characterize and appropriately treat missing data in a way that preserves the scientific integrity of the crash‑severity modeling process. Missingness is not simply a technical inconvenience; it reflects underlying data‑collection mechanisms, reporting practices, and structural features of the SWITRS system. For this reason, the first step is to examine the pattern and magnitude of missing values across all predictors. The variables exhibiting the highest levels of missingness—RAMP_INTERSECTION, ALCOHOL_INVOLVED, LOCATION_TYPE, and PCF_VIOL_SUBSECTION—are not missing at random. Their absence is tied to the nature of the crash event and the reporting protocol. For example, a large proportion of crashes do not occur on ramps, so the ramp indicator is legitimately absent. Alcohol involvement is frequently coded as “unknown” unless a test is administered, meaning that missingness reflects uncertainty rather than omission. Similarly, location type is only recorded when the officer explicitly classifies the site, and PCF subsections are only present when the violation has a definable subsection. Because these missing values carry substantive meaning, removing the affected rows would distort the underlying distribution of crash types and introduce bias. Instead, the scientifically appropriate approach is to encode these missing values as their own category, preserving the informational content of “unknown” or “not applicable” conditions.
# Moderate missingness appears in the geospatial variables LATITUDE and LONGITUDE, which represent failed geocoding attempts rather than conceptual absence. These missing values do not reflect meaningful crash characteristics but rather limitations in the geospatial matching process. Given the size of the dataset and the fact that these failures are not systematically related to severity, imputing the median latitude and longitude is a defensible strategy. This approach maintains the spatial structure of the dataset without discarding a substantial number of observations. Alternatively, one could remove rows missing both coordinates, but the proportion is small enough that median imputation avoids unnecessary data loss while preserving analytical power.
# Variables with low levels of missingness—such as PCF_VIOLATION, CHP_VEHTYPE_AT_FAULT, TOW_AWAY, and STATE_HWY_IND—are treated using mode imputation. These fields are categorical and their missingness is minimal, making the mode an appropriate and statistically stable replacement. This ensures that the dataset remains complete without materially altering the distribution of these predictors.
# The final step is to apply a structured, reproducible missing‑data strategy aligned with best practices in crash‑severity research. Categorical variables with meaningful or systematic missingness are assigned an explicit “Unknown” category, preserving the interpretability and avoiding the introduction of bias through deletion. Numeric variables, particularly geospatial coordinates, are imputed using the median to maintain central tendency without being influenced by outliers. This dual‑strategy approach ensures that the dataset remains analytically robust, avoids outcome leakage, and retains the full informational value of the SWITRS reporting structure. With missingness fully addressed, the dataset is now suitable for encoding, scaling, exploratory analysis, and subsequent model development.

# %%
import numpy as np

# Identify Categorical and Numeric Columns

cat_cols = model_df.select_dtypes(exclude=[np.number]).columns
num_cols = model_df.select_dtypes(include=[np.number]).columns

# %%
# One-Hot encode Categorical Variables

df_encoded = pd.get_dummies(model_df, columns=cat_cols, drop_first=True)
df_encoded.head()
# Out:
#    Year  DAY_OF_WEEK  COLLISION_TIME  IS_WEEKEND  CHP_ROAD_TYPE  PARTY_COUNT  \
# 0  2021            1            1440           0              0            3
# 1  2021            7            1153           1              0            3
# 2  2021            2            1400           0              0            2
# 3  2021            2            1330           0              0            2
# 4  2021            1             856           0              0            2
#
#     LATITUDE   LONGITUDE  Total Registrations  Motorcycle Registration  ...  \
# 0  33.920551 -117.801407            7989032.0                 155065.0  ...
# 1  33.920551 -117.801407            7989032.0                 155065.0  ...
# 2  33.920551 -117.801407            7989032.0                 155065.0  ...
# 3  33.920551 -117.801407            7989032.0                 155065.0  ...
# 4  33.936798 -118.343903            7989032.0                 155065.0  ...
#
#    CITY_WALNUT  CITY_WEST COVINA  CITY_WEST HOLLYWOOD  CITY_WESTLAKE VILLAGE  \
# 0        False             False                False                  False
# 1        False             False                False                  False
# 2        False             False                False                  False
# 3        False             False                False                  False
# 4        False             False                False                  False
#
#    CITY_WESTMINSTER  CITY_WHITTIER  CITY_WILDOMAR  CITY_YORBA LINDA  \
# 0             False          False          False             False
# 1             False          False          False             False
# 2             False          False          False             False
# 3             False          False          False             False
# 4             False          False          False             False
#
#    CITY_YUCAIPA  CITY_YUCCA VALLEY
# 0         False              False
# 1         False              False
# 2         False              False
# 3         False              False
# 4         False              False
#
# [5 rows x 473 columns]

# %% [markdown]
# One‑hot encoding was essential in this study because the majority of the predictors used in the crash‑severity model are categorical, nominal, or non‑ordinal in nature. In scientific modeling, categorical variables cannot be directly interpreted by statistical or machine‑learning algorithms because these methods operate on numerical inputs. More importantly, assigning arbitrary numeric codes to categories (for example, “1 = Clear weather, 2 = Rain, 3 = Fog”) would incorrectly impose an artificial ordering on variables that have no inherent rank structure. This would distort the relationships the model learns and introduce bias into the estimation of severity effects. One‑hot encoding resolves this by transforming each category into a binary indicator, allowing the model to treat each category as a distinct, unordered condition. This preserves the true structure of the data and prevents the model from inferring nonexistent ordinal relationships.
# The use of one‑hot encoding is particularly important in crash‑severity research because many of the predictors—such as lighting condition, roadway surface condition, collision type, and primary collision factor—represent discrete operational states rather than continuous or ordered phenomena. These variables describe qualitative aspects of the crash environment and rider exposure, and their categories often reflect mutually exclusive conditions with different implications for crash dynamics. By encoding each category as its own binary variable, the modeling framework can estimate the independent association of each condition with injury severity. This approach enhances interpretability and aligns with the theoretical understanding that different roadway or environmental states may exert unique influences on crash outcomes.
# One‑hot encoding also supports methodological rigor by ensuring that the model does not rely on implicit numerical relationships that lack empirical justification. For example, treating “Daylight,” “Dark – Street Lights,” and “Dark – No Street Lights” as numeric values would imply that one condition is “greater” or “less” than another, which has no physical or conceptual meaning. The binary representation produced through one‑hot encoding eliminates this risk and allows the model to evaluate each lighting condition independently. This is especially important when modeling nonlinear or interaction effects, as the encoded variables allow the model to capture complex relationships between environmental conditions and severity outcomes without imposing structural constraints.
# Finally, one‑hot encoding enhances the comparability and stability of the modeling process. Because the dataset includes predictors with varying numbers of categories—some with only two levels and others with dozens—encoding them into a consistent binary format ensures that all categorical variables contribute to the model in a standardized way. This supports downstream processes such as scaling, correlation analysis, and feature‑importance estimation. In the context of this study, where the goal is to evaluate how roadway, environmental, temporal, and spatial factors influence motorcycle injury severity, one‑hot encoding provides a scientifically sound and statistically robust foundation for modeling categorical predictors without distorting their underlying meaning.

# %%
# Scaling Predictors Since they span different Numeric Ranges

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_encoded[num_cols] = scaler.fit_transform(df_encoded[num_cols])

# %% [markdown]
# Standardization was applied to a specific subset of predictors in this study—namely the numeric, continuous, and spatial variables—because these variables exist on vastly different numerical scales and units of measurement. The predictors targeted for standardization included COLLISION_TIME, Year, LATITUDE, LONGITUDE, PARTY_COUNT, and the full set of county‑level registration variables (Total Registrations, Motorcycle Registration, Auto Registration, Truck Registration, Other Registration). exhibit substantial differences in magnitude, variance, and measurement units. These predictors range from small integers to multi‑million‑scale registration counts and geospatial coordinates. StandardScaler applies a z‑score transformation that centers each variable at zero and scales it to unit variance, ensuring that no predictor disproportionately influences the model solely due to its numerical scale. This is essential for maintaining statistical validity in models that rely on gradient‑based optimization or distance metrics.
# The choice of standardization over alternative normalization methods is grounded in both theoretical and empirical considerations. Min–max normalization, for example, rescales variables to a fixed 0–1 range, but it is highly sensitive to extreme values and compresses the distribution in ways that can distort meaningful variation. This is particularly problematic for registration variables, which naturally exhibit large inter‑county differences that should not be artificially flattened. Max‑abs scaling suffers from similar limitations and is most appropriate for data already centered around zero, which is not the case for temporal or spatial predictors. Robust scaling, which uses medians and interquartile ranges, is advantageous when variables contain extreme outliers; however, the numeric predictors in this dataset do not exhibit pathological outlier behavior, and robust scaling would unnecessarily down‑weight legitimate variation in exposure‑based predictors.
# Standardization also preserves the interpretability of the transformed variables in a way that aligns with the goals of crash‑severity modeling. Because the z‑score transformation retains the shape of each variable’s distribution, the resulting standardized predictors reflect meaningful deviations from typical values. For example, a one‑standard‑deviation increase in  corresponds to a shift toward later‑day crashes, while a one‑standard‑deviation increase in registration counts reflects higher‑exposure counties. This interpretability is lost under min–max scaling, where values become unitless proportions detached from their original context. Standardization therefore supports both model performance and substantive interpretation.
# Finally, standardization enhances numerical stability during model training. Algorithms such as logistic regression, neural networks, and support vector machines converge more efficiently when predictors are standardized, reducing the risk of unstable coefficient estimates or slow optimization. Given the heterogeneity of the numeric predictors in this study—spanning temporal, spatial, and exposure‑based domains—standardization provides a unified and scientifically defensible scaling approach. By selecting StandardScaler over alternative normalization methods, the analysis ensures that the model evaluates each numeric predictor based on its relationship to injury severity rather than on artifacts of scale or distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Class Imbalance Bar Graph where # 1 = Fatal , 2 = Severe Injury , 3 = Visible Injury , 4 = Complaint of Pain

sns.countplot(x='COLLISION_SEVERITY', data=model_df)
plt.title("Distribution of Collision Severity")
plt.show()

# %% [markdown]
# It is easily seen where Fatal Accidents are far less creating a Class Imbalance in Severity Modeling

# %%
# Corrrelation Heatmap

plt.figure(figsize=(14,10))
sns.heatmap(df_encoded.corr(), cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Show Correlation Table By Making Dataframe

corr_table = (
    df_encoded.corr()['COLLISION_SEVERITY']
    .drop('COLLISION_SEVERITY')
    .sort_values(ascending=False)
)

corr_df = corr_table.reset_index()
corr_df.columns = ['Predictor', 'Correlation_with_Severity']
corr_df
# Out:
#                  Predictor  Correlation_with_Severity
# 0      TYPE_OF_COLLISION_B                   0.132095
# 1     PCF_VIOL_CATEGORY_07                   0.110121
# 2    PCF_VIOLATION_21658.0                   0.110117
# 3               LIGHTING_A                   0.097096
# 4            HIT_AND_RUN_M                   0.079874
# ..                     ...                        ...
# 467  PCF_VIOLATION_23152.0                  -0.117759
# 468   PCF_VIOL_CATEGORY_01                  -0.123446
# 469     ALCOHOL_INVOLVED_Y                  -0.128273
# 470             TOW_AWAY_Y                  -0.230291
# 471          CHP_ROAD_TYPE                        NaN
#
# [472 rows x 2 columns]

# %%
# Display Top 20 Predictors

corr_df.head(20)
# Out:
#                        Predictor  Correlation_with_Severity
# 0            TYPE_OF_COLLISION_B                   0.132095
# 1           PCF_VIOL_CATEGORY_07                   0.110121
# 2          PCF_VIOLATION_21658.0                   0.110117
# 3                     LIGHTING_A                   0.097096
# 4                  HIT_AND_RUN_M                   0.079874
# 5            TIME_OF_DAY_Morning                   0.061084
# 6            TYPE_OF_COLLISION_C                   0.056127
# 7        STWD_VEHTYPE_AT_FAULT_A                   0.056033
# 8        CHP_VEHTYPE_AT_FAULT_99                   0.051516
# 9        CHP_VEHTYPE_AT_FAULT_01                   0.045637
# 10  CHP_VEHTYPE_AT_FAULT_Unknown                   0.045466
# 11                CITY_SAN DIEGO                   0.042098
# 12                INTERSECTION_N                   0.040764
# 13         PCF_VIOLATION_21703.0                   0.038375
# 14               STATE_HWY_IND_Y                   0.038006
# 15           TYPE_OF_COLLISION_H                   0.037947
# 16          PCF_VIOL_CATEGORY_04                   0.037172
# 17              County_SAN DIEGO                   0.034791
# 18            TIME_OF_DAY_Midday                   0.034330
# 19         PCF_VIOLATION_21755.0                   0.033709

# %%
# Identifying Negativly Correlated Predictors

corr_df.tail(20)
# Out:
#                    Predictor  Correlation_with_Severity
# 452      TYPE_OF_COLLISION_A                  -0.053894
# 453                LONGITUDE                  -0.058939
# 454    PCF_VIOLATION_21801.0                  -0.063302
# 455               LIGHTING_C                  -0.063661
# 456    PCF_VIOL_SUBSECTION_F                  -0.066056
# 457              DAY_OF_WEEK                  -0.070530
# 458         CITY_LOS ANGELES                  -0.072665
# 459               IS_WEEKEND                  -0.074185
# 460               LIGHTING_D                  -0.078955
# 461      CITY_UNINCORPORATED                  -0.079031
# 462  STWD_VEHTYPE_AT_FAULT_C                  -0.082513
# 463      TYPE_OF_COLLISION_D                  -0.082908
# 464  CHP_VEHTYPE_AT_FAULT_02                  -0.096020
# 465      TYPE_OF_COLLISION_E                  -0.097181
# 466        TIME_OF_DAY_Night                  -0.117032
# 467    PCF_VIOLATION_23152.0                  -0.117759
# 468     PCF_VIOL_CATEGORY_01                  -0.123446
# 469       ALCOHOL_INVOLVED_Y                  -0.128273
# 470               TOW_AWAY_Y                  -0.230291
# 471            CHP_ROAD_TYPE                        NaN

# %%
# Must Fix CHP_ROAD_TYPE since it is NaN and is a classification Code As Opposed to Numeric Quantity
# A case of mistaken Pandas Num/Cat variable

model_df['CHP_ROAD_TYPE'].dtype
# Out:
# dtype('int64')

# %%
import pandas as pd

# --- Ensure model_df exists ---
if 'model_df' not in globals():
    if 'df_merged' in globals() and 'predictors' in globals() and 'outcome' in globals():
        model_df = df_merged[predictors + [outcome]].copy()
    else:
        raise ValueError("df_merged, predictors, or outcome is not defined in the current session.")

# %%
# Convert to Categorical

model_df['CHP_ROAD_TYPE'] = model_df['CHP_ROAD_TYPE'].astype('category')

# %%
#Fill Missing Values to Unkown

if 'Unknown' not in model_df['CHP_ROAD_TYPE'].cat.categories:
    model_df['CHP_ROAD_TYPE'] = model_df['CHP_ROAD_TYPE'].cat.add_categories('Unknown')

model_df['CHP_ROAD_TYPE'] = model_df['CHP_ROAD_TYPE'].fillna('Unknown')

# %%
#Re-encode

df_encoded = pd.get_dummies(model_df, drop_first=True)

# %%
[col for col in df_encoded.columns if 'CHP_ROAD_TYPE' in col]
# Out:
# ['CHP_ROAD_TYPE_Unknown']

# %%
model_df['CHP_ROAD_TYPE'].value_counts(dropna=False)
# Out:
# CHP_ROAD_TYPE
# 0          19721
# Unknown        0
# Name: count, dtype: int64

# %% [markdown]
# CHP_ROAD_TYPE has no variation therefore it cannot be used for prediction and must be dropped.

# %%
# Drop Column CHP_ROAD_TYPE

model_df = model_df.drop(columns=['CHP_ROAD_TYPE'])
df_encoded = df_encoded.drop(columns=['CHP_ROAD_TYPE_Unknown'], errors='ignore')

# %%
# Checking Columns for removal

'CHP_ROAD_TYPE' in model_df.columns
# Out:
# False

# %%
# Identify any other ZERO Variance Predictors

# Identify zero-variance predictors
zero_var = [col for col in df_encoded.columns if df_encoded[col].nunique() <= 1]

print("Zero-variance predictors:", zero_var)
# Out:
# Zero-variance predictors: []

# %%
# Rebuildkng Clean Correlation Table

corr_table = (
    df_encoded.corr()['COLLISION_SEVERITY']
    .drop('COLLISION_SEVERITY')
    .sort_values(ascending=False)
)

corr_df = corr_table.reset_index()
corr_df.columns = ['Predictor', 'Correlation_with_Severity']
corr_df
# Out:
#                  Predictor  Correlation_with_Severity
# 0      TYPE_OF_COLLISION_B                   0.132095
# 1     PCF_VIOL_CATEGORY_07                   0.110121
# 2    PCF_VIOLATION_21658.0                   0.110117
# 3               LIGHTING_A                   0.097096
# 4            HIT_AND_RUN_M                   0.079874
# ..                     ...                        ...
# 466      TIME_OF_DAY_Night                  -0.117032
# 467  PCF_VIOLATION_23152.0                  -0.117759
# 468   PCF_VIOL_CATEGORY_01                  -0.123446
# 469     ALCOHOL_INVOLVED_Y                  -0.128273
# 470             TOW_AWAY_Y                  -0.230291
#
# [471 rows x 2 columns]

# %%
# Meaningful Predictors (Cleaned)

corr_df[abs(corr_df['Correlation_with_Severity']) > 0.05]
# Out:
#                    Predictor  Correlation_with_Severity
# 0        TYPE_OF_COLLISION_B                   0.132095
# 1       PCF_VIOL_CATEGORY_07                   0.110121
# 2      PCF_VIOLATION_21658.0                   0.110117
# 3                 LIGHTING_A                   0.097096
# 4              HIT_AND_RUN_M                   0.079874
# 5        TIME_OF_DAY_Morning                   0.061084
# 6        TYPE_OF_COLLISION_C                   0.056127
# 7    STWD_VEHTYPE_AT_FAULT_A                   0.056033
# 8    CHP_VEHTYPE_AT_FAULT_99                   0.051516
# 452      TYPE_OF_COLLISION_A                  -0.053894
# 453                LONGITUDE                  -0.058939
# 454    PCF_VIOLATION_21801.0                  -0.063302
# 455               LIGHTING_C                  -0.063661
# 456    PCF_VIOL_SUBSECTION_F                  -0.066056
# 457              DAY_OF_WEEK                  -0.070530
# 458         CITY_LOS ANGELES                  -0.072665
# 459               IS_WEEKEND                  -0.074185
# 460               LIGHTING_D                  -0.078955
# 461      CITY_UNINCORPORATED                  -0.079031
# 462  STWD_VEHTYPE_AT_FAULT_C                  -0.082513
# 463      TYPE_OF_COLLISION_D                  -0.082908
# 464  CHP_VEHTYPE_AT_FAULT_02                  -0.096020
# 465      TYPE_OF_COLLISION_E                  -0.097181
# 466        TIME_OF_DAY_Night                  -0.117032
# 467    PCF_VIOLATION_23152.0                  -0.117759
# 468     PCF_VIOL_CATEGORY_01                  -0.123446
# 469       ALCOHOL_INVOLVED_Y                  -0.128273
# 470               TOW_AWAY_Y                  -0.230291

# %% [markdown]
# The correlation structure produced reflects a coherent pattern of severity‑related mechanisms that aligns well with established motorcycle crash‑injury research. Several predictors demonstrated meaningful positive associations with injury severity, indicating that these conditions or behaviors tend to occur more frequently in higher‑severity crashes. The strongest of these were collision‑configuration variables such as **TYPE_OF_COLLISION_B** and **TYPE_OF_COLLISION_C**, which typically represent angular or head‑on impact geometries. These crash types are known to generate higher kinetic energy transfer and expose motorcyclists to more direct impact forces, which explains their elevated correlation with severe outcomes. Behavioral risk factors also emerged prominently: **PCF_VIOL_CATEGORY_07** and **PCF_VIOLATION_21658.0**—categories often associated with improper turning, unsafe lane changes, or other hazardous maneuvers—showed strong positive associations with severity. These findings reinforce the role of rider or driver decision‑making in shaping crash energy and injury potential. Environmental visibility also contributed meaningfully, with **LIGHTING_A** indicating that low‑visibility conditions are disproportionately represented in severe crashes, consistent with literature documenting reduced hazard detection and increased reaction times in dark environments.
#
# Several predictors exhibited negative correlations with severity, reflecting conditions more common in lower‑severity or property‑damage‑only crashes. The strongest of these was **TOW_AWAY_Y**, which is expected: tow‑away designations are typically assigned to crashes involving vehicle disablement rather than severe injury, and thus appear more frequently in low‑severity events. Additional negative associations were observed for specific PCF categories such as **PCF_VIOL_CATEGORY_01** and **PCF_VIOLATION_23152.0**, suggesting that some violation types correspond to lower‑energy crash scenarios. Lighting categories such as **LIGHTING_C** and **LIGHTING_D**, which generally represent daylight or well‑lit conditions, also showed negative correlations, consistent with the protective effect of improved visibility. Although **ALCOHOL_INVOLVED_Y** displayed a negative correlation, this pattern should not be interpreted substantively; alcohol involvement in SWITRS is known to suffer from structured missingness and under‑reporting, particularly in severe crashes, and the observed correlation likely reflects reporting artifacts rather than a true inverse relationship.
#
# Taken together, the correlation profile indicates that the most influential severity‑related domains in this dataset are collision mechanics, hazardous behavioral violations, and environmental visibility. These findings align closely with established crash‑severity literature and provide a coherent empirical foundation for subsequent modeling.

# %%
# Creating Highest Powered Predictor Data Frames using Pearson's R

# Predictors with |r| > 0.1
corr_01 = corr_df[abs(corr_df['Correlation_with_Severity']) > 0.1]

# Predictors with |r| > 0.075
corr_0075 = corr_df[abs(corr_df['Correlation_with_Severity']) > 0.075]

# %%
print("Variable names >0.1:", corr_01['Predictor'].tolist())
print("Variable names >0.075:", corr_0075['Predictor'].tolist())
# Out:
# Variable names >0.1: ['TYPE_OF_COLLISION_B', 'PCF_VIOL_CATEGORY_07', 'PCF_VIOLATION_21658.0', 'TIME_OF_DAY_Night', 'PCF_VIOLATION_23152.0', 'PCF_VIOL_CATEGORY_01', 'ALCOHOL_INVOLVED_Y', 'TOW_AWAY_Y']
# Variable names >0.075: ['TYPE_OF_COLLISION_B', 'PCF_VIOL_CATEGORY_07', 'PCF_VIOLATION_21658.0', 'LIGHTING_A', 'HIT_AND_RUN_M', 'LIGHTING_D', 'CITY_UNINCORPORATED', 'STWD_VEHTYPE_AT_FAULT_C', 'TYPE_OF_COLLISION_D', 'CHP_VEHTYPE_AT_FAULT_02', 'TYPE_OF_COLLISION_E', 'TIME_OF_DAY_Night', 'PCF_VIOLATION_23152.0', 'PCF_VIOL_CATEGORY_01', 'ALCOHOL_INVOLVED_Y', 'TOW_AWAY_Y']

# %% [markdown]
# SWITRS/TIMS definitions
#
# # 🚦 Type of Collision (TYPE_OF_COLLISION_*)
# These come from the SWITRS *Type of Collision* field. Your one‑hot encoded variables represent specific categories.
#
# ### Meaning of variables
# - **TYPE_OF_COLLISION_B — Broadside**
#   Front of one vehicle strikes the side of another (classic “T‑bone”).
#
# - **TYPE_OF_COLLISION_D — Sideswipe, Same Direction**
#   Vehicles traveling the same direction scrape or collide along their sides.
#
# - **TYPE_OF_COLLISION_E — Sideswipe, Opposite Direction**
#   Vehicles traveling opposite directions scrape or collide along their sides.
#
# ### Full SWITRS classes
# - A — Head‑On
# - B — Broadside
# - C — Rear‑End
# - D — Sideswipe (Same Direction)
# - E — Sideswipe (Opposite Direction)
# - F — Hit Object
# - G — Overturned
# - H — Vehicle/Pedestrian
# - I — Other
# - J — Not Stated
#
# ---
#
# # 🚓 Primary Collision Factor Category (PCF_VIOL_CATEGORY_*)
# These are grouped violation categories assigned by the officer.
#
# ### Meaning of variables
# - **PCF_VIOL_CATEGORY_01 — Driving Under the Influence (DUI)**
# - **PCF_VIOL_CATEGORY_07 — Unsafe Speed**
#
# ### Full SWITRS PCF categories
# - 01 — Driving Under the Influence
# - 02 — Impeding Traffic
# - 03 — Unsafe Speed
# - 04 — Following Too Closely
# - 05 — Wrong Side of Road
# - 06 — Improper Passing
# - 07 — Unsafe Lane Change
# - 08 — Improper Turning
# - 09 — Automobile Right‑of‑Way
# - 10 — Pedestrian Right‑of‑Way
# - 11 — Pedestrian Violation
# - 12 — Traffic Signals and Signs
# - 13 — Hazardous Parking
# - 14 — Lights
# - 15 — Brakes
# - 16 — Other Equipment
# - 17 — Other Hazardous Violation
# - 18 — Other Than Driver
# - 19 — Unknown
# - 20 — Fell Asleep
#
# ---
#
# # 🚓 Specific PCF Violations (PCF_VIOLATION_*)
# These are California Vehicle Code (CVC) violations.
#
# ### Meaning of variables
# - **PCF_VIOLATION_21658.0 — Unsafe Lane Change**
#   CVC 21658: Failure to maintain lane / weaving.
#
# - **PCF_VIOLATION_23152.0 — DUI Alcohol**
#   CVC 23152: Driving under the influence of alcohol.
#
# ### Notes
# There are hundreds of CVC codes; your dataset includes only those present in your crashes.
#
# ---
#
# # 🌙 Time of Day (TIME_OF_DAY_*)
# TIMS recodes time into categorical bins.
#
# ### Meaning of variable
# - **TIME_OF_DAY_Night — Nighttime (typically 9 PM–5 AM)**
#
# ### Full TIMS time‑of‑day classes
# - Morning
# - Afternoon
# - Evening
# - Night
#
# (Some TIMS versions use 4‑hour bins; your encoded version uses the 4‑category scheme.)
#
# ---
#
# # 🍺 Alcohol Involvement (ALCOHOL_INVOLVED_Y)
# From the SWITRS *Alcohol Involved* field.
#
# ### Meaning
# - **ALCOHOL_INVOLVED_Y — Alcohol was involved**
#   Officer indicated drinking by at least one party.
#
# ### Full classes
# - Y — Yes
# - blank — No
#
# ---
#
# # 🚚 Tow‑Away Indicator (TOW_AWAY_Y)
# From the *Towed Vehicle* field.
#
# ### Meaning
# - **TOW_AWAY_Y — At least one vehicle was towed due to damage**
#
# ### Full classes
# - Y — Yes
# - blank — No
#
# ---
#
# # 💡 Lighting Conditions (LIGHTING_*)
# From SWITRS *Lighting* field.
#
# ### Meaning of your variables
# - **LIGHTING_A — Daylight**
# - **LIGHTING_D — Dark, Street Lights On**
#
# ### Full SWITRS lighting classes
# - A — Daylight
# - B — Dusk/Dawn
# - C — Dark, Street Lights Off
# - D — Dark, Street Lights On
# - E — Dark, No Street Lights
# - F — Other
# - G — Not Stated
#
# ---
#
# # 🏃 Hit and Run (HIT_AND_RUN_*)
# From SWITRS *Hit and Run* field.
#
# ### Meaning of your variable
# - **HIT_AND_RUN_M — Misdemeanor Hit and Run**
#
# ### Full classes
# - F — Felony
# - M — Misdemeanor
# - blank — Not Hit and Run
#
# ---
#
# # 🏙 City Indicator (CITY_UNINCORPORATED)
# From the *City* field.
#
# ### Meaning
# - **CITY_UNINCORPORATED — Crash occurred outside city limits**
#   County‑administered area.
#
# ### Full classes
# - Named incorporated cities
# - Unincorporated
#
# ---
#
# # 🏍 Standardized Vehicle Type at Fault (STWD_VEHTYPE_AT_FAULT_*)
# From TIMS standardized vehicle type coding.
#
# ### Meaning of your variable
# - **STWD_VEHTYPE_AT_FAULT_C — Motorcycle at fault**
#
# ### Full TIMS standardized vehicle type classes
# - A — Passenger Car
# - B — Pickup/Panel Truck
# - C — Motorcycle
# - D — Truck/Tractor
# - E — Bus
# - F — Emergency Vehicle
# - G — Bicycle
# - H — Pedestrian
# - I — Other
# - J — Unknown
#
# ---
#
# # 🚗 CHP Vehicle Type at Fault (CHP_VEHTYPE_AT_FAULT_*)
# This uses CHP’s numeric vehicle type codes.
#
# ### Meaning of variable
# - **CHP_VEHTYPE_AT_FAULT_02 — Passenger Car**
#
# ### Common CHP vehicle type codes
# - 01 — Motorcycle
# - 02 — Passenger Car
# - 03 — Pickup
# - 04 — Van
# - 05 — Truck
# - 06 — Tractor/Trailer
# - 07 — Bus
# - 08 — Emergency Vehicle
# - 09 — Bicycle
# - 10 — Pedestrian
# - 11+ — Other/Unknown

# %%
# Extract Predictor Lists
predictors_01 = corr_01['Predictor'].tolist()
predictors_0075 = corr_0075['Predictor'].tolist()

# Build New Dataframes
df_corr_01 = df_encoded[predictors_01 + ['COLLISION_SEVERITY']]
df_corr_0075 = df_encoded[predictors_0075 + ['COLLISION_SEVERITY']]

# %%
print("Shape of df_corr_01:", df_corr_01.shape)
print("Shape of df_corr_0075:", df_corr_0075.shape)
# Out:
# Shape of df_corr_01: (19721, 9)
# Shape of df_corr_0075: (19721, 17)

# %%
predictors_of_0075 = [
    'TYPE_OF_COLLISION_B',
    'TYPE_OF_COLLISION_D',
    'TYPE_OF_COLLISION_E',
    'PCF_VIOL_CATEGORY_01',
    'PCF_VIOL_CATEGORY_07',
    'PCF_VIOLATION_21658.0',
    'PCF_VIOLATION_23152.0',
    'TIME_OF_DAY_Night',
    'ALCOHOL_INVOLVED_Y',
    'TOW_AWAY_Y',
    'LIGHTING_A',
    'LIGHTING_D',
    'HIT_AND_RUN_M',
    'CITY_UNINCORPORATED',
    'STWD_VEHTYPE_AT_FAULT_C',
    'CHP_VEHTYPE_AT_FAULT_02'
]

# %% [markdown]
# Above included are the dummy variables created so in order to get summary statistics we need to use Original Variables and Original Dataset

# %%
original_vars_0075 = [
    'TYPE_OF_COLLISION',
    'PCF_VIOL_CATEGORY',
    'PCF_VIOLATION',
    'TIME_OF_DAY',
    'ALCOHOL_INVOLVED',
    'TOW_AWAY',
    'LIGHTING',
    'HIT_AND_RUN',
    'CITY',
    'STWD_VEHTYPE_AT_FAULT',
    'CHP_VEHTYPE_AT_FAULT'
]

# %%
df_original_0075 = model_df[original_vars_0075 + ['COLLISION_SEVERITY']]

# %%
# Summary Statistics for Original Categorical Variables
for col in original_vars_0075:
    print(f"\n--- {col} ---")
    print(model_df[col].value_counts(dropna=False))
# Out:
# --- TYPE_OF_COLLISION ---
# TYPE_OF_COLLISION
# D    4918
# B    4079
# C    3750
# F    2997
# E    1994
# A     897
# H     829
# G     155
# -     102
# Name: count, dtype: int64
#
# --- PCF_VIOL_CATEGORY ---
# PCF_VIOL_CATEGORY
# 03    5807
# 08    4055
# 09    3197
# 07    2268
# 12     871
# 01     844
# 00     531
# 06     453
# 05     362
# 18     319
# 17     216
# 04     170
# 21     145
# 22     103
# -       90
# 11      79
# 9       55
# 3       28
# 10      24
# 0       22
# 8       20
# 02      14
# 16      12
# 6       10
# 7        6
# 15       5
# 5        4
# 13       3
# 14       3
# 1        3
# 4        2
# Name: count, dtype: int64
#
# --- PCF_VIOLATION ---
# PCF_VIOLATION
# 22350.0    5814
# 22107.0    3780
# 21658.0    2275
# 21801.0    1709
# Unknown     963
#            ...
# 21701.0       1
# 22453.0       1
# 20001.0       1
# 25651.0       1
# 23105.0       1
# Name: count, Length: 115, dtype: int64
#
# --- TIME_OF_DAY ---
# TIME_OF_DAY
# Evening    6180
# Midday     6089
# Morning    3836
# Night      3616
# Name: count, dtype: int64
#
# --- ALCOHOL_INVOLVED ---
# ALCOHOL_INVOLVED
# Unknown    18247
# Y           1474
# Name: count, dtype: int64
#
# --- TOW_AWAY ---
# TOW_AWAY
# Y          11020
# N           8559
# Unknown      142
# Name: count, dtype: int64
#
# --- LIGHTING ---
# LIGHTING
# A    13550
# C     4170
# D     1173
# B      746
# -       44
# E       38
# Name: count, dtype: int64
#
# --- HIT_AND_RUN ---
# HIT_AND_RUN
# N    17586
# F     1702
# M      433
# Name: count, dtype: int64
#
# --- CITY ---
# CITY
# UNINCORPORATED      3844
# LOS ANGELES         2820
# SAN DIEGO           1820
# LONG BEACH           542
# RIVERSIDE            420
#                     ...
# LA HABRA HEIGHTS       2
# AVALON                 2
# LAGUNA WOODS           2
# INDIAN WELLS           1
# SIERRA MADRE           1
# Name: count, Length: 184, dtype: int64
#
# --- STWD_VEHTYPE_AT_FAULT ---
# STWD_VEHTYPE_AT_FAULT
# C    10544
# A     5948
# -     2140
# D      697
# O      105
# F       68
# N       68
# L       34
# E       31
# G       30
# I       22
# J       17
# B        9
# M        4
# H        3
# K        1
# Name: count, dtype: int64
#
# --- CHP_VEHTYPE_AT_FAULT ---
# CHP_VEHTYPE_AT_FAULT
# 02         9408
# 01         4330
# 07         1296
# -          1162
# 99          873
# 22          707
# 03          694
# Unknown     359
# 06          341
# 08          198
# 05           96
# 60           65
# 25           34
# 04           32
# 26           27
# 11           18
# 27           15
# 48           15
# 55            8
# 23            6
# 31            5
# 72            4
# 21            3
# 13            3
# 94            3
# 86            3
# 85            2
# 76            2
# 75            1
# 56            1
# 87            1
# 43            1
# 41            1
# 12            1
# 45            1
# 10            1
# 09            1
# 20            1
# 44            1
# 82            1
# Name: count, dtype: int64

# %%
# Normalized Summary Statistics for Categorical Variables
for col in original_vars_0075:
    print(col)
    print(model_df[col].value_counts(normalize=True))
# Out:
# TYPE_OF_COLLISION
# TYPE_OF_COLLISION
# D    0.249379
# B    0.206835
# C    0.190153
# F    0.151970
# E    0.101110
# A    0.045485
# H    0.042036
# G    0.007860
# -    0.005172
# Name: proportion, dtype: float64
# PCF_VIOL_CATEGORY
# PCF_VIOL_CATEGORY
# 03    0.294458
# 08    0.205618
# 09    0.162111
# 07    0.115004
# 12    0.044166
# 01    0.042797
# 00    0.026926
# 06    0.022970
# 05    0.018356
# 18    0.016176
# 17    0.010953
# 04    0.008620
# 21    0.007353
# 22    0.005223
# -     0.004564
# 11    0.004006
# 9     0.002789
# 3     0.001420
# 10    0.001217
# 0     0.001116
# 8     0.001014
# 02    0.000710
# 16    0.000608
# 6     0.000507
# 7     0.000304
# 15    0.000254
# 5     0.000203
# 13    0.000152
# 14    0.000152
# 1     0.000152
# 4     0.000101
# Name: proportion, dtype: float64
# PCF_VIOLATION
# PCF_VIOLATION
# 22350.0    0.294813
# 22107.0    0.191674
# 21658.0    0.115359
# 21801.0    0.086659
# Unknown    0.048831
#              ...
# 21701.0    0.000051
# 22453.0    0.000051
# 20001.0    0.000051
# 25651.0    0.000051
# 23105.0    0.000051
# Name: proportion, Length: 115, dtype: float64
# TIME_OF_DAY
# TIME_OF_DAY
# Evening    0.313372
# Midday     0.308757
# Morning    0.194513
# Night      0.183358
# Name: proportion, dtype: float64
# ALCOHOL_INVOLVED
# ALCOHOL_INVOLVED
# Unknown    0.925257
# Y          0.074743
# Name: proportion, dtype: float64
# TOW_AWAY
# TOW_AWAY
# Y          0.558795
# N          0.434004
# Unknown    0.007200
# Name: proportion, dtype: float64
# LIGHTING
# LIGHTING
# A    0.687085
# C    0.211450
# D    0.059480
# B    0.037828
# -    0.002231
# E    0.001927
# Name: proportion, dtype: float64
# HIT_AND_RUN
# HIT_AND_RUN
# N    0.891740
# F    0.086304
# M    0.021956
# Name: proportion, dtype: float64
# CITY
# CITY
# UNINCORPORATED      0.194919
# LOS ANGELES         0.142995
# SAN DIEGO           0.092287
# LONG BEACH          0.027483
# RIVERSIDE           0.021297
#                       ...
# LA HABRA HEIGHTS    0.000101
# AVALON              0.000101
# LAGUNA WOODS        0.000101
# INDIAN WELLS        0.000051
# SIERRA MADRE        0.000051
# Name: proportion, Length: 184, dtype: float64
# STWD_VEHTYPE_AT_FAULT
# STWD_VEHTYPE_AT_FAULT
# C    0.534658
# A    0.301607
# -    0.108514
# D    0.035343
# O    0.005324
# F    0.003448
# N    0.003448
# L    0.001724
# E    0.001572
# G    0.001521
# I    0.001116
# J    0.000862
# B    0.000456
# M    0.000203
# H    0.000152
# K    0.000051
# Name: proportion, dtype: float64
# CHP_VEHTYPE_AT_FAULT
# CHP_VEHTYPE_AT_FAULT
# 02         0.477055
# 01         0.219563
# 07         0.065717
# -          0.058922
# 99         0.044268
# 22         0.035850
# 03         0.035191
# Unknown    0.018204
# 06         0.017291
# 08         0.010040
# 05         0.004868
# 60         0.003296
# 25         0.001724
# 04         0.001623
# 26         0.001369
# 11         0.000913
# 27         0.000761
# 48         0.000761
# 55         0.000406
# 23         0.000304
# 31         0.000254
# 72         0.000203
# 21         0.000152
# 13         0.000152
# 94         0.000152
# 86         0.000152
# 85         0.000101
# 76         0.000101
# 75         0.000051
# 56         0.000051
# 87         0.000051
# 43         0.000051
# 41         0.000051
# 12         0.000051
# 45         0.000051
# 10         0.000051
# 09         0.000051
# 20         0.000051
# 44         0.000051
# 82         0.000051
# Name: proportion, dtype: float64

# %%
# EDA

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", context="notebook")

# %%
# Histogram + KDE

numeric_cols = df_encoded.select_dtypes(include=['int64','float64']).columns

df_encoded[numeric_cols].hist(figsize=(18, 14), bins=30)
plt.tight_layout()
plt.show()

# %%
# Boxplot Outlier Detection of Numeric Predictors

plt.figure(figsize=(14, 8))
sns.boxplot(data=df_encoded[numeric_cols], orient='h')
plt.title("Boxplots of Numeric Predictors")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", context="notebook")

# Choose categorical predictors to visualize
categorical_vars = [
    'TIME_OF_DAY',
    'LIGHTING',
    'TYPE_OF_COLLISION',
    'PCF_VIOL_CATEGORY'
]

# Create a large figure with subplots
fig, axes = plt.subplots(
    nrows=len(categorical_vars),
    ncols=1,
    figsize=(14, 4 * len(categorical_vars)),
    constrained_layout=True
)

# Loop through each categorical variable and plot a violin plot
for ax, cat in zip(axes, categorical_vars):
    sns.violinplot(
        data=model_df,
        x=cat,
        y='COLLISION_SEVERITY',
        ax=ax,
        inner='quartile',
        cut=0
    )
    ax.set_title(f"Severity Distribution by {cat}", fontsize=14)
    ax.set_xlabel(cat)
    ax.set_ylabel("Collision Severity")
    ax.tick_params(axis='x', rotation=45)

plt.show()

# %%
sns.lmplot(
    data=df_encoded,
    x='PARTY_COUNT',
    y='COLLISION_SEVERITY',
    height=6,
    scatter_kws={'alpha':0.3}
)
plt.title("Severity vs Longitude with Trendline")
plt.show()

# %%
# Correlation Heatmap with Top 20 Predictors

top20 = corr_df.head(20)['Predictor'].tolist()
sns.heatmap(
    df_encoded[top20 + ['COLLISION_SEVERITY']].corr(),
    annot=False,
    cmap='coolwarm'
)
plt.title("Top 20 Predictors Correlation Heatmap")
plt.show()

# %%
# Outcome Distibution Barplot
plt.figure(figsize=(8, 5))
sns.countplot(data=model_df, x='COLLISION_SEVERITY')
plt.title("Distribution of Collision Severity")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", context="notebook")

# Categorical variables to visualize
categorical_vars = [
    'TIME_OF_DAY',
    'LIGHTING',
    'TYPE_OF_COLLISION',
    'PCF_VIOL_CATEGORY',
    'HIT_AND_RUN',
    'DAY_OF_WEEK',
    'CITY'
]

# Create figure with one subplot per categorical variable
fig, axes = plt.subplots(
    nrows=len(categorical_vars),
    ncols=1,
    figsize=(16, 4 * len(categorical_vars)),
    constrained_layout=True
)

for ax, cat in zip(axes, categorical_vars):

    # If the category has too many levels (e.g., CITY), show top 10
    if model_df[cat].nunique() > 12:
        top_vals = (
            model_df[cat]
            .value_counts()
            .head(10)
            .index
        )
        plot_df = model_df[model_df[cat].isin(top_vals)]
    else:
        plot_df = model_df

    sns.barplot(
        data=plot_df,
        x=cat,
        y='COLLISION_SEVERITY',
        estimator='mean',
        ax=ax,
        errorbar=None
    )

    ax.set_title(f"Mean Collision Severity by {cat}", fontsize=14)
    ax.set_xlabel(cat)
    ax.set_ylabel("Mean Severity")
    ax.tick_params(axis='x', rotation=45)

plt.show()

# %%
# Pairplots for Key Predictors

sns.pairplot(
    df_encoded[['COLLISION_SEVERITY', 'PARTY_COUNT', 'LONGITUDE', 'LATITUDE']],
    diag_kind='kde'
)
plt.show()

# %%
# Severity by Day of Week

sns.boxplot(data=model_df, x='DAY_OF_WEEK', y='COLLISION_SEVERITY')
plt.title("Severity by Day of Week")
plt.show()

# %%
# Severity by Lighting Condition

sns.boxplot(data=model_df, x='LIGHTING', y='COLLISION_SEVERITY')
plt.title("Severity by Lighting Condition")
plt.show()

# %%
# Severity by Collision Type

sns.boxplot(data=model_df, x='TYPE_OF_COLLISION', y='COLLISION_SEVERITY')
plt.xticks(rotation=45)
plt.title("Severity by Collision Type")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Raincloud Plot for Categorical Variables

sns.set(style="whitegrid", context="notebook")

categorical_vars = [
    'TIME_OF_DAY',
    'LIGHTING',
    'TYPE_OF_COLLISION',
    'PCF_VIOL_CATEGORY'
]

fig, axes = plt.subplots(
    nrows=len(categorical_vars),
    ncols=1,
    figsize=(16, 5 * len(categorical_vars)),
    constrained_layout=True
)

for ax, cat in zip(axes, categorical_vars):
    sns.violinplot(
        data=model_df,
        x=cat,
        y='COLLISION_SEVERITY',
        ax=ax,
        inner=None,
        cut=0,
        linewidth=1
    )
    sns.boxplot(
        data=model_df,
        x=cat,
        y='COLLISION_SEVERITY',
        ax=ax,
        width=0.2,
        showcaps=True,
        boxprops={'facecolor':'white'},
        showfliers=False
    )
    sns.stripplot(
        data=model_df,
        x=cat,
        y='COLLISION_SEVERITY',
        ax=ax,
        color='black',
        alpha=0.2,
        jitter=True
    )
    ax.set_title(f"Raincloud Plot: Severity by {cat}", fontsize=14)
    ax.tick_params(axis='x', rotation=45)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ridge Plot Composite to show Overlapping Distribution 'Time of Day'

sns.set(style="white", context="notebook")

cat = 'TIME_OF_DAY'
unique_vals = model_df[cat].unique()

fig, ax = plt.subplots(figsize=(12, 8))

for i, val in enumerate(unique_vals):
    subset = model_df[model_df[cat] == val]
    sns.kdeplot(
        subset['COLLISION_SEVERITY'],
        fill=True,
        alpha=0.6,
        linewidth=1,
        label=str(val),
        ax=ax
    )

ax.set_title(f"Ridge Plot: Severity Distribution by {cat}", fontsize=14)
ax.set_xlabel("Collision Severity")
ax.legend(title=cat)
plt.show()

# %%
# Ridge Plot Composite to show Overlapping Distribution 'TYPE_OF_COLLISION'

sns.set(style="white", context="notebook")

cat = 'TYPE_OF_COLLISION'
unique_vals = model_df[cat].unique()

fig, ax = plt.subplots(figsize=(12, 8))

for i, val in enumerate(unique_vals):
    subset = model_df[model_df[cat] == val]
    sns.kdeplot(
        subset['COLLISION_SEVERITY'],
        fill=True,
        alpha=0.6,
        linewidth=1,
        label=str(val),
        ax=ax
    )

ax.set_title(f"Ridge Plot: Severity Distribution by {cat}", fontsize=14)
ax.set_xlabel("Collision Severity")
ax.legend(title=cat)
plt.show()

# %%
import seaborn as sns

#Facet Grid of Histograms
g = sns.FacetGrid(
    model_df,
    col="TIME_OF_DAY",
    col_wrap=4,
    height=3.5,
    sharex=True,
    sharey=True
)

g.map(sns.histplot, "COLLISION_SEVERITY", bins=10, kde=True)
g.fig.suptitle("Severity Distribution by Time of Day", y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", context="notebook")

fig, axes = plt.subplots(
    nrows=3,
    ncols=2,
    figsize=(18, 18),
    constrained_layout=True
)

# 1. Histogram of severity
sns.histplot(
    data=model_df,
    x='COLLISION_SEVERITY',
    bins=10,
    kde=True,
    ax=axes[0,0]
)
axes[0,0].set_title("Severity Distribution")

# 2. Boxplot by Time of Day
sns.boxplot(
    data=model_df,
    x='TIME_OF_DAY',
    y='COLLISION_SEVERITY',
    ax=axes[0,1]
)
axes[0,1].set_title("Severity by Time of Day")
axes[0,1].tick_params(axis='x', rotation=45)

# 3. Violin plot by Lighting
sns.violinplot(
    data=model_df,
    x='LIGHTING',
    y='COLLISION_SEVERITY',
    ax=axes[1,0]
)
axes[1,0].set_title("Severity by Lighting")
axes[1,0].tick_params(axis='x', rotation=45)

# 4. Scatter with trendline
sns.regplot(
    data=df_encoded,
    x='LONGITUDE',
    y='COLLISION_SEVERITY',
    scatter_kws={'alpha':0.3},
    ax=axes[1,1]
)
axes[1,1].set_title("Severity vs Longitude")

# 5. Barplot by Collision Type
sns.barplot(
    data=model_df,
    x='TYPE_OF_COLLISION',
    y='COLLISION_SEVERITY',
    estimator='mean',
    ax=axes[2,0]
)
axes[2,0].set_title("Mean Severity by Collision Type")
axes[2,0].tick_params(axis='x', rotation=45)

# 6. KDE of severity
sns.kdeplot(
    data=model_df,
    x='COLLISION_SEVERITY',
    fill=True,
    ax=axes[2,1]
)
axes[2,1].set_title("Severity KDE")

plt.show()

# %%
# Summary Statistics for Numeric Variables

numeric_cols = df_encoded.select_dtypes(include=['int64','float64']).columns

numeric_summary = model_df[numeric_cols].describe().T
numeric_summary
# Out:
#                            count          mean           std           min  \
# Year                     19721.0  2.022015e+03  8.091608e-01  2.021000e+03
# DAY_OF_WEEK              19721.0  4.200446e+00  1.953161e+00  1.000000e+00
# COLLISION_TIME           19721.0  1.421351e+03  5.254137e+02  0.000000e+00
# IS_WEEKEND               19721.0  3.138786e-01  4.640795e-01  0.000000e+00
# PARTY_COUNT              19721.0  1.890472e+00  6.763695e-01  1.000000e+00
# LATITUDE                 19721.0  3.383913e+01  4.239187e-01  3.250380e+01
# LONGITUDE                19721.0 -1.177185e+02  4.895355e-01 -1.214954e+02
# Total Registrations      19721.0  4.835483e+06  2.627461e+06  1.967257e+06
# Motorcycle Registration  19721.0  1.004444e+05  4.435882e+04  4.365000e+04
# Auto Registration        19721.0  3.780775e+06  2.186668e+06  1.353131e+06
# Truck Registration       19721.0  7.378340e+05  3.438532e+05  3.880130e+05
# Other Registration       19721.0  2.164292e+05  6.012959e+04  1.127170e+05
# COLLISION_SEVERITY       19721.0  2.893413e+00  8.281298e-01  1.000000e+00
#
#                                   25%           50%           75%  \
# Year                     2.021000e+03  2.022000e+03  2.023000e+03
# DAY_OF_WEEK              3.000000e+00  4.000000e+00  6.000000e+00
# COLLISION_TIME           1.105000e+03  1.522000e+03  1.805000e+03
# IS_WEEKEND               0.000000e+00  0.000000e+00  1.000000e+00
# PARTY_COUNT              2.000000e+00  2.000000e+00  2.000000e+00
# LATITUDE                 3.381108e+01  3.392055e+01  3.401256e+01
# LONGITUDE               -1.179932e+02 -1.178014e+02 -1.174009e+02
# Total Registrations      2.876125e+06  2.997003e+06  7.848098e+06
# Motorcycle Registration  5.714000e+04  8.545100e+04  1.504640e+05
# Auto Registration        2.239148e+06  2.289997e+06  6.291868e+06
# Truck Registration       4.240720e+05  4.941610e+05  1.136152e+06
# Other Registration       1.774130e+05  1.906960e+05  2.804760e+05
# COLLISION_SEVERITY       2.000000e+00  3.000000e+00  3.000000e+00
#
#                                   max
# Year                     2.023000e+03
# DAY_OF_WEEK              7.000000e+00
# COLLISION_TIME           2.500000e+03
# IS_WEEKEND               1.000000e+00
# PARTY_COUNT              1.100000e+01
# LATITUDE                 3.996733e+01
# LONGITUDE               -1.142160e+02
# Total Registrations      7.989032e+06
# Motorcycle Registration  1.550650e+05
# Auto Registration        6.386830e+06
# Truck Registration       1.150957e+06
# Other Registration       2.961800e+05
# COLLISION_SEVERITY       4.000000e+00

# %%
# Summary Statistics for Categorical Variables

categorical_cols = model_df.select_dtypes(include=['object','category']).columns

categorical_summary = {
    col: model_df[col].value_counts(dropna=False)
    for col in categorical_cols
}

categorical_summary
# Out:
# {'TIME_OF_DAY': TIME_OF_DAY
#  Evening    6180
#  Midday     6089
#  Morning    3836
#  Night      3616
#  Name: count, dtype: int64,
#  'WEATHER_1': WEATHER_1
#  A    17977
#  B     1462
#  C      138
#  -       86
#  E       27
#  G       21
#  F        7
#  D        3
#  Name: count, dtype: int64,
#  'LIGHTING': LIGHTING
#  A    13550
#  C     4170
#  D     1173
#  B      746
#  -       44
#  E       38
#  Name: count, dtype: int64,
#  'ROAD_SURFACE': ROAD_SURFACE
#  A    19189
#  B      374
#  -       92
#  D       58
#  C        7
#  H        1
#  Name: count, dtype: int64,
#  'ROAD_COND_1': ROAD_COND_1
#  H    18829
#  D      419
#  A      125
#  B      105
#  G       97
#  -       76
#  C       56
#  E        8
#  F        6
#  Name: count, dtype: int64,
#  'STATE_HWY_IND': STATE_HWY_IND
#  N          11372
#  Y           8337
#  Unknown       12
#  Name: count, dtype: int64,
#  'LOCATION_TYPE': LOCATION_TYPE
#  Unknown    14135
#  H           5110
#  R            328
#  I            148
#  Name: count, dtype: int64,
#  'INTERSECTION': INTERSECTION
#  N    14876
#  Y     4776
#  -       69
#  Name: count, dtype: int64,
#  'RAMP_INTERSECTION': RAMP_INTERSECTION
#  Unknown    19170
#  -            278
#  5            140
#  4            117
#  6              8
#  1              4
#  3              3
#  2              1
#  Name: count, dtype: int64,
#  'CONTROL_DEVICE': CONTROL_DEVICE
#  D    13797
#  A     5760
#  -       83
#  B       66
#  C       15
#  Name: count, dtype: int64,
#  'TYPE_OF_COLLISION': TYPE_OF_COLLISION
#  D    4918
#  B    4079
#  C    3750
#  F    2997
#  E    1994
#  A     897
#  H     829
#  G     155
#  -     102
#  Name: count, dtype: int64,
#  'PRIMARY_COLL_FACTOR': PRIMARY_COLL_FACTOR
#  A    18794
#  D      453
#  C      319
#  B      101
#  -       54
#  Name: count, dtype: int64,
#  'PCF_CODE_OF_VIOL': PCF_CODE_OF_VIOL
#  -    19721
#  Name: count, dtype: int64,
#  'PCF_VIOL_CATEGORY': PCF_VIOL_CATEGORY
#  03    5807
#  08    4055
#  09    3197
#  07    2268
#  12     871
#  01     844
#  00     531
#  06     453
#  05     362
#  18     319
#  17     216
#  04     170
#  21     145
#  22     103
#  -       90
#  11      79
#  9       55
#  3       28
#  10      24
#  0       22
#  8       20
#  02      14
#  16      12
#  6       10
#  7        6
#  15       5
#  5        4
#  13       3
#  14       3
#  1        3
#  4        2
#  Name: count, dtype: int64,
#  'PCF_VIOLATION': PCF_VIOLATION
#  22350.0    5814
#  22107.0    3780
#  21658.0    2275
#  21801.0    1709
#  Unknown     963
#             ...
#  21701.0       1
#  22453.0       1
#  20001.0       1
#  25651.0       1
#  23105.0       1
#  Name: count, Length: 115, dtype: int64,
#  'PCF_VIOL_SUBSECTION': PCF_VIOL_SUBSECTION
#  Unknown    11627
#  A           7450
#  B            307
#  G             98
#  C             87
#  F             62
#  D             39
#  5             23
#  1             19
#  I              4
#  E              4
#  2              1
#  Name: count, dtype: int64,
#  'HIT_AND_RUN': HIT_AND_RUN
#  N    17586
#  F     1702
#  M      433
#  Name: count, dtype: int64,
#  'TOW_AWAY': TOW_AWAY
#  Y          11020
#  N           8559
#  Unknown      142
#  Name: count, dtype: int64,
#  'ALCOHOL_INVOLVED': ALCOHOL_INVOLVED
#  Unknown    18247
#  Y           1474
#  Name: count, dtype: int64,
#  'STWD_VEHTYPE_AT_FAULT': STWD_VEHTYPE_AT_FAULT
#  C    10544
#  A     5948
#  -     2140
#  D      697
#  O      105
#  F       68
#  N       68
#  L       34
#  E       31
#  G       30
#  I       22
#  J       17
#  B        9
#  M        4
#  H        3
#  K        1
#  Name: count, dtype: int64,
#  'CHP_VEHTYPE_AT_FAULT': CHP_VEHTYPE_AT_FAULT
#  02         9408
#  01         4330
#  07         1296
#  -          1162
#  99          873
#  22          707
#  03          694
#  Unknown     359
#  06          341
#  08          198
#  05           96
#  60           65
#  25           34
#  04           32
#  26           27
#  11           18
#  27           15
#  48           15
#  55            8
#  23            6
#  31            5
#  72            4
#  21            3
#  13            3
#  94            3
#  86            3
#  85            2
#  76            2
#  75            1
#  56            1
#  87            1
#  43            1
#  41            1
#  12            1
#  45            1
#  10            1
#  09            1
#  20            1
#  44            1
#  82            1
#  Name: count, dtype: int64,
#  'County': County
#  LOS ANGELES       8365
#  SAN DIEGO         4211
#  RIVERSIDE         2445
#  ORANGE            2400
#  SAN BERNARDINO    2300
#  Name: count, dtype: int64,
#  'CITY': CITY
#  UNINCORPORATED      3844
#  LOS ANGELES         2820
#  SAN DIEGO           1820
#  LONG BEACH           542
#  RIVERSIDE            420
#                      ...
#  LA HABRA HEIGHTS       2
#  AVALON                 2
#  LAGUNA WOODS           2
#  INDIAN WELLS           1
#  SIERRA MADRE           1
#  Name: count, Length: 184, dtype: int64}

# %%
# stacked percentage bar chart

def plot_stacked_risk_profile_with_labels(df, feature_col, target_col='COLLISION_SEVERITY'):

    # 1. Prepare Data
    ct = pd.crosstab(df[feature_col], df[target_col])
    ct_pct = ct.div(ct.sum(1), axis=0)

    # 2. Sort by Risk
    danger_score = ct_pct.get(1, 0) + ct_pct.get(2, 0)
    ct_pct = ct_pct.loc[danger_score.sort_values(ascending=False).index]
    risk_palette = {1: '#8B0000', 2: '#FF4500', 3: '#DAA520', 4: '#2E8B57'}
    colors = [risk_palette.get(x, 'grey') for x in ct_pct.columns]

    # 3. Plot
    ax = ct_pct.plot(kind='bar', stacked=True, color=colors, figsize=(14, 7), width=0.85)
    for c in ax.containers:
        labels = [f'{v.get_height()*100:.0f}%' if v.get_height() > 0.02 else '' for v in c]
        ax.bar_label(c, labels=labels, label_type='center',
                     color='white', fontsize=10, weight='bold', padding=0)

    # 4. Formatting
    plt.title(f'Severity Distribution by {feature_col}\n(Sorted by Risk)', fontsize=16, fontweight='bold')
    plt.ylabel('Proportion of Crashes', fontsize=12)
    plt.xlabel(feature_col, fontsize=12)

    plt.legend(title='Severity', labels=['1: Fatal', '2: Severe', '3: Visible', '4: Pain'],
               bbox_to_anchor=(1.02, 1), loc='upper left')

    plt.xticks(rotation=45, ha='right')
    plt.yticks([])
    sns.despine(left=True)

    plt.tight_layout()
    plt.show()


plot_stacked_risk_profile_with_labels(model_df, 'TYPE_OF_COLLISION')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

RANDOM_STATE = 42

# Split data into train and validation sets

def prepare_and_split_data(df, target_col, features, test_size=0.15, val_size=0.15):
    # First split: Separate the final test set 15%
    X = df[features]
    y = df[target_col]

    X_train_val, X_test, y_train_val, y_test = train_test_split(
        X, y, test_size=test_size, random_state=42)

    # Second split: Separate training and validation from the remaining 85%
    relative_val_size = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(
        X_train_val, y_train_val, test_size=relative_val_size, random_state=42)

    return X_train, X_val, X_test, y_train, y_val, y_test

target = 'COLLISION_SEVERITY'

feature_list = df_encoded.columns.drop(target).tolist()

X_train, X_val, X_test, y_train, y_val, y_test = prepare_and_split_data(
    df_encoded, target, feature_list)

print(f"Training: {len(X_train)} | Validation: {len(X_val)} | Test: {len(X_test)}")
# Out:
# Training: 13804 | Validation: 2958 | Test: 2959

# %%
# Regression

import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler

lr_pipeline = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        class_weight='balanced',
        solver='lbfgs',
        max_iter=1000,
        random_state=RANDOM_STATE))

# Fit on Training Data
lr_pipeline.fit(X_train, y_train)

val_preds_lr = lr_pipeline.predict(X_val)
val_probs_lr = lr_pipeline.predict_proba(X_val)

# Evaluate
print(f"ROC-AUC Score: {roc_auc_score(y_val, val_probs_lr, multi_class='ovr', average='weighted'):.4f}")
print(classification_report(y_val, val_preds_lr))

feature_names = X_train.columns

logistic_model = lr_pipeline.named_steps['logisticregression']

coefficients_for_class_1 = logistic_model.coef_[0]

# Odds Ratios
odds_ratios = np.exp(coefficients_for_class_1)

or_df = pd.DataFrame({
    'Feature': feature_names,
    'Odds_Ratio': odds_ratios
}).sort_values(by='Odds_Ratio', ascending=False)

print("Top Risk Factors - Odds Ratios")
print(or_df.head(40))
# Out:
# ROC-AUC Score: 0.6227
#               precision    recall  f1-score   support
#
#            1       0.14      0.50      0.22       148
#            2       0.39      0.35      0.37       784
#            3       0.54      0.33      0.41      1319
#            4       0.35      0.45      0.39       707
#
#     accuracy                           0.37      2958
#    macro avg       0.36      0.41      0.35      2958
# weighted avg       0.44      0.37      0.39      2958
#
# Top Risk Factors - Odds Ratios
#                      Feature  Odds_Ratio
# 45            INTERSECTION_N    2.308136
# 8    Motorcycle Registration    2.290662
# 46            INTERSECTION_Y    2.146572
# 228               TOW_AWAY_Y    1.875625
# 286    County_SAN BERNARDINO    1.779817
# 27            ROAD_SURFACE_A    1.715955
# 72      PCF_VIOL_CATEGORY_01    1.704219
# 28            ROAD_SURFACE_B    1.622822
# 245  CHP_VEHTYPE_AT_FAULT_01    1.613319
# 285         County_RIVERSIDE    1.547301
# 260  CHP_VEHTYPE_AT_FAULT_22    1.530324
# 57          CONTROL_DEVICE_D    1.472693
# 54          CONTROL_DEVICE_A    1.456143
# 161    PCF_VIOLATION_21954.0    1.455379
# 114    PCF_VIOLATION_21228.0    1.419811
# 69     PRIMARY_COLL_FACTOR_D    1.393506
# 251  CHP_VEHTYPE_AT_FAULT_07    1.386225
# 158    PCF_VIOLATION_21950.0    1.370252
# 284            County_ORANGE    1.368876
# 4                PARTY_COUNT    1.343089
# 180    PCF_VIOLATION_22350.0    1.328243
# 229       ALCOHOL_INVOLVED_Y    1.321361
# 74      PCF_VIOL_CATEGORY_03    1.320431
# 61       TYPE_OF_COLLISION_D    1.318655
# 79      PCF_VIOL_CATEGORY_08    1.304776
# 62       TYPE_OF_COLLISION_E    1.300486
# 116    PCF_VIOLATION_21235.0    1.275925
# 30            ROAD_SURFACE_D    1.250126
# 80      PCF_VIOL_CATEGORY_09    1.246843
# 249  CHP_VEHTYPE_AT_FAULT_05    1.242983
# 204    PCF_VIOLATION_24250.0    1.225910
# 126    PCF_VIOLATION_21650.0    1.223153
# 123    PCF_VIOLATION_21460.0    1.219010
# 163    PCF_VIOLATION_21956.0    1.218801
# 222    PCF_VIOL_SUBSECTION_G    1.201825
# 221    PCF_VIOL_SUBSECTION_F    1.186841
# 173    PCF_VIOLATION_22107.0    1.186661
# 246  CHP_VEHTYPE_AT_FAULT_02    1.180430
# 287         County_SAN DIEGO    1.169522
# 252  CHP_VEHTYPE_AT_FAULT_08    1.144605

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

classes = lr_pipeline.named_steps["logisticregression"].classes_
n_classes = len(classes)

y_val_bin = label_binarize(y_val, classes=classes)

fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], val_probs_lr[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Micro-average ROC, treat every class decision equally
fpr["micro"], tpr["micro"], _ = roc_curve(y_val_bin.ravel(), val_probs_lr.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Macro-average ROC, average across classes
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
mean_tpr = np.zeros_like(all_fpr)

for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot
plt.figure(figsize=(9, 7))

# Per-class curves
for i, cls in enumerate(classes):
    plt.plot(
        fpr[i],
        tpr[i],
        lw=2,
        label=f"Class {cls} (AUC = {roc_auc[i]:.3f})")

plt.plot(
    fpr["micro"],
    tpr["micro"],
    lw=2,
    linestyle="--",
    label=f"micro-average (AUC = {roc_auc['micro']:.3f})")
plt.plot(
    fpr["macro"],
    tpr["macro"],
    lw=2,
    linestyle=":",
    label=f"macro-average (AUC = {roc_auc['macro']:.3f})")

plt.plot([0, 1], [0, 1], lw=1, linestyle="--")

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curvew - Logistic Regression")
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Random Forest

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Fit
rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1)

rf.fit(X_train, y_train)

# Evaluate
rf_preds = rf.predict(X_val)
print("Random Forest")
print(classification_report(y_val, rf_preds))

# ROC–AUC
rf_probs = rf.predict_proba(X_val)
classes = rf.classes_

roc_auc_w = roc_auc_score(
    y_val,
    rf_probs,
    multi_class="ovr",
    average="weighted")
roc_auc_macro = roc_auc_score(
    y_val,
    rf_probs,
    multi_class="ovr",
    average="macro")

print(f"ROC–AUC (weighted): {roc_auc_w:.4f}")
print(f"ROC–AUC (macro):    {roc_auc_macro:.4f}")

# ROC Curve
y_val_bin = label_binarize(y_val, classes=classes)
n_classes = len(classes)

fpr, tpr, roc_auc = {}, {}, {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], rf_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(y_val_bin.ravel(), rf_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
mean_tpr = np.zeros_like(all_fpr)

for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot
plt.figure(figsize=(9, 7))

for i, cls in enumerate(classes):
    plt.plot(
        fpr[i],
        tpr[i],
        lw=2,
        label=f"Class {cls} (AUC = {roc_auc[i]:.3f})")

plt.plot(
    fpr["micro"],
    tpr["micro"],
    linestyle="--",
    lw=2,
    label=f"micro-average (AUC = {roc_auc['micro']:.3f})")
plt.plot(
    fpr["macro"],
    tpr["macro"],
    linestyle=":",
    lw=2,
    label=f"macro-average (AUC = {roc_auc['macro']:.3f})")

plt.plot([0, 1], [0, 1], linestyle="--", lw=1)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves — Random Forest")
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Random Forest
#               precision    recall  f1-score   support
#
#            1       0.15      0.47      0.23       148
#            2       0.45      0.35      0.39       784
#            3       0.55      0.34      0.42      1319
#            4       0.35      0.54      0.43       707
#
#     accuracy                           0.40      2958
#    macro avg       0.38      0.42      0.37      2958
# weighted avg       0.46      0.40      0.41      2958
#
# ROC–AUC (weighted): 0.6450
# ROC–AUC (macro):    0.6797

# %%
#XGBoost

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import classification_report

xgb_preds = xgb_model.predict(X_val)
print("XGBoost")
print(classification_report(y_val_xgb, xgb_preds))

# ROC–AUC
xgb_probs = xgb_model.predict_proba(X_val)

roc_auc_w = roc_auc_score(
    y_val_xgb,
    xgb_probs,
    multi_class="ovr",
    average="weighted")
roc_auc_macro = roc_auc_score(
    y_val_xgb,
    xgb_probs,
    multi_class="ovr",
    average="macro")

print(f"ROC–AUC (weighted): {roc_auc_w:.4f}")
print(f"ROC–AUC (macro):    {roc_auc_macro:.4f}")

# ROC Curve Plot
classes = np.unique(y_train_xgb)
y_val_bin = label_binarize(y_val_xgb, classes=classes)
n_classes = len(classes)

fpr, tpr, roc_auc = {}, {}, {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], xgb_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(y_val_bin.ravel(), xgb_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
mean_tpr = np.zeros_like(all_fpr)

for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro_curve"] = auc(fpr["macro"], tpr["macro"])

# Plot
plt.figure(figsize=(9, 7))

for i in range(n_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        lw=2,
        label=f"Class {classes[i]} (AUC = {roc_auc[i]:.3f})")

plt.plot(
    fpr["micro"],
    tpr["micro"],
    linestyle="--",
    lw=2,
    label=f"micro-average (AUC = {roc_auc['micro']:.3f})")

plt.plot(
    fpr["macro"],
    tpr["macro"],
    linestyle=":",
    lw=2,
    label=f"macro-average (AUC = {roc_auc['macro_curve']:.3f})")

plt.plot([0, 1], [0, 1], linestyle="--", lw=1)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves — XGBoost")
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2087/1203973531.py in <cell line: 0>()
#       8 from sklearn.metrics import classification_report
#       9
# ---> 10 xgb_preds = xgb_model.predict(X_val)
#      11 print("XGBoost")
#      12 print(classification_report(y_val_xgb, xgb_preds))
#
# NameError: name 'xgb_model' is not defined
